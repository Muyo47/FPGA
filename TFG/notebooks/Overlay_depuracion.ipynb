# %%
# Overlay personalizado. Version de pruebas

from pynq import Overlay
from pynq import MMIO
over = Overlay("/home/xilinx/jupyter_notebooks/TFG_PRUEBAS/bitTEST.bit")
over.download()

# Para acceder a base adress y el rango, window -> adress editor

BASE_ADDRESS = 0x43C00000  # Direccion base del registro s00 AXI
slave0 = MMIO(BASE_ADDRESS, 0x10000)   # Rango de 64kB (0x1000 para 4kB)

# De momento, la estructura del registro queda asi:
# Bit 0 -> HandshakeBit (write enable BRAM bit)
# Bits 1 a 8 -> direccion BRAM
# Bits 9 a 16 -> datos a escribir
# Bit 31 (solo debug)
# Bit 32 (solo debug)

# slave0.write(0, 0x1)  # Hex
slave0.write(0, 0b00000000000000000000000000000001)  # Binario

val = slave0.read(0)  # Lee el registro AXI
print(f"Valor leido: {val:#010x}")

#!pwd
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [15], in <cell line: 5>()
#       3 from pynq import Overlay
#       4 from pynq import MMIO
# ----> 5 over = Overlay("/home/xilinx/jupyter_notebooks/TFG_PRUEBAS/bitTEST.bit")
#       6 over.download()
#       8 # Para acceder a base adress y el rango, window -> adress editor
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/overlay.py:315, in __init__(self, bitfile_name, dtbo, download, ignore_version, device, gen_cache)
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/bitstream.py:118, in __init__(self, bitfile_name, dtbo, partial, device)
#
# OSError: Bitstream file /home/xilinx/jupyter_notebooks/TFG_PRUEBAS/bitTEST.bit does not exist.

# %%
#slave0.write(0, 0x0)  # Escribir un '0' en el bit 0 del registro base
slave0.write(0, 0b00000000000000000000000000000011)

val = slave0.read(0)  # Leer el contenido del registro
print(f"Valor leido: {val:#010x}")
# Out:
# Valor leido: 0x00000003

# %%
#slave0.write(0, 0x1)  # Escribir un '1' en el bit 0 del registro base
slave0.write(0, 0b00000000000000000000000000000010)

val = slave0.read(0)  # Leer el contenido del registro
print(f"Valor leido: {val:#010x}")
# Out:
# Valor leido: 0x00000002
